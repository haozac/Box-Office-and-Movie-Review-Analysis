# %%
import time
import re
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import nltk
import textblob

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://did.sarawak.gov.my/page-0-0-1563-Recorded-Flood-Event-in-Sarawak-2021-2.html")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Zac\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-7-faddbd72468c>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')
soup_list = soup.findAll('tr')
len(soup_list)
# Out:
# 62

# %%
for soup in soup_list:
    print(soup.text)
# Out:
#
#     Loading...
#
#
# Historical Flood Events Recorded in Sarawak From 1946 - 2021
#
#
# Events
# Division
# Affected Flood Areas
# Flood Height *
# Comments
#
#
#  YEAR 2021
#
#
# 04/12/2021 @ 1630pm - 1800pm
# Lundu, Kuching
# Pekan Lundu
# 0.05m - 0.1m
# Fenomena air pasang besar yang menyebabkan air Sungai Batang Kayan naik dan melimpah ke kawasan yang berdekatan dengan sungai
#
#
# Kampung Sileng Melayu
# 0.05m - 0.1m
#
#
# Kampung Sileng Dayak
# 0.05m - 0.1m
#
#
# Kampung Stunggang Melayu Baru
# 0.05m - 0.1m
#
#
# Kampung Stunggang Melayu Lama
# 0.05m - 0.1m
#
#
# Kampung Semunin
# 0.05m - 0.1m
#
#
# 05/12/2021 @ 1600pm - 1800pm
# Kabong, Betong
# Empayang
# 0.3m - 0.5m
# Fenomena air pasang besar dan hujan yang menyebabkan air Sungai Penang dan Sungai Krian naik serta melimpah ke kawasan yang rendah
#
#
# Kampung Batang Maro
# 0.3m - 0.5m
#
#
# Pasar Kabong
# 0.5m -1.0m
#
#
# 05/12/2021 @ 1630pm - 1900pm
# Lundu, Kuching
# Pekan Lundu
# 0.05m - 0.3m
# ...

# %%
import re
soup_list = soup.findAll("tr")
soup_list.pop(0)
len(soup_list)
# Out:
# 200

# %%
movie_list = []
all_price = []

for soup in soup_list:
    movie_name = soup.find("a", attrs={"class":"a-link-normal"}).text
    movie_price = soup.find("td", attrs={"class":"a-text-right mojo-field-type-money"}).text
    movie_list.append(movie_name)
    all_price.append(movie_price)

all_price
# Out:
# ['$2,847,246,203',
#  '$2,797,501,328',
#  '$2,201,647,264',
#  '$2,069,521,700',
#  '$2,048,359,754',
#  '$1,670,516,444',
#  '$1,662,899,439',
#  '$1,518,815,515',
#  '$1,515,341,399',
#  '$1,450,026,933',
#  '$1,402,809,540',
#  '$1,368,892,000',
#  '$1,347,597,973',
#  '$1,342,321,665',
#  '$1,332,698,830',
#  '$1,310,466,296',
#  '$1,281,508,100',
#  '$1,273,576,220',
#  '$1,243,089,244',
#  '$1,236,005,118',
#  '$1,214,811,252',
#  '$1,159,444,662',
#  '$1,153,337,496',
#  '$1,148,485,886',
#  '$1,146,030,912',
#  '$1,131,927,996',
#  '$1,128,462,972',
#  '$1,123,794,079',
#  '$1,108,569,499',
#  '$1,104,054,072',
#  '$1,081,142,612',
#  '$1,074,419,384',
#  '$1,074,149,279',
#  '$1,073,394,593',
#  '$1,066,970,811',
#  '$1,066,179,747',
#  '$1,063,611,805',
#  '$1,056,057,720',
#  '$1,050,693,953',
#  '$1,045,713,802',
#  '$1,034,800,131',
#  '$1,033,928,303',
#  '$1,028,570,942',
#  '$1,027,082,707',
#  '$1,025,468,216',
#  '$1,024,121,104',
#  '$1,017,003,568',
# ...
